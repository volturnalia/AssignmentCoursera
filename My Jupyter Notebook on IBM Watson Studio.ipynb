# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bruce Heidenreich**
# Hedge Fund Manager

# %% [markdown]
# *Data Science is of interest to me because the recollection of data is sky-rocketing in value. It is a profitable career path.*

# %% [markdown]
# ### This code displays a famous movie quote

# %%
quote = "Say hello to my little friend."
print(quote)
# Out:
# Say hello to my little friend.

# %% [markdown]
# content above horizontal line
# ***
# content below horizontal line
#
# 1. Queens Gambit
# 2. London system
# 3. Sicillian Defense
#
# [click me](http://google.com)
